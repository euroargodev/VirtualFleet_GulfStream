# %%
import sys
import numpy as np
import pandas as pd
import xarray as xr

from datetime import timedelta
import json
from ifremer_utilities import load_json, save_json
# Out:
# /Users/gmaze/miniconda3/envs/virtualfleet/lib/python3.8/site-packages/pyproj/__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
def load_db(db_file):
    with open(db_file, 'r') as stream:
        db = json.load(stream)
    return db

DB = load_db("../data/simulations_db.json")
# DB = load_db("839031.datarmor0.json")

# %%
DB['simulations']['run-template']
# Out:
# {'comment': None,
#  'runs-on': 'datarmor',
#  'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#   'start': '01/01/2008',
#   'end': '31/12/2018',
#   'float-number': 1648},
#  'velocity-field': {'name': 'GLORYS-NATL'},
#  'argo-configuration': {'name': 'default', 'file': None},
#  'execute': {'duration': 'days=30',
#   'step': 'minutes=5',
#   'record': 'seconds=3600/2',
#   'dask_hpcconfig': {'name': 'datarmor-local', 'client': None}},
#  'pbs': {'jobid': None,
#   'log': {'debug': None},
#   'submit': {'file': '${repo}/local_work/simu04.pbs',
#    'queue': 'mpi',
#    'walltime': '48:00:00',
#    'mem': '250g'},
#   'resources_used': {'cpupercent': None,
#    'cput': None,
#    'mem': None,
#    'ncpus': None,
#    'vmem': None,
#    'walltime': None}},
#  'output': {'file': None,
#   'size-on-disk': None,
#   'array-size': {'traj': None, 'obs': None},
#   'index': None}}

# %%
run_list = DB['simulations']
run_list.keys()
# Out:
# dict_keys(['run-template', 'run-1010801', 'run-1009216', 'run-1009214', 'run-1009213', 'run-0923846', 'run-0913494', 'run-0912543', 'run-0908795', 'run-0885949', 'run-0851194', 'run-0711242', 'run-0691822', 'run-0653526', 'run-0614790', 'run-0613257', 'run-0542230', 'run-0538001'])

# %%
def sort_dict_by_value(d, sort=None):
    if sort is None:
        return d
    else:
        reverse = False if sort == 'ascent' else True
        return dict(sorted(d.items(), key=lambda x: x[1], reverse=reverse))


def read_a_file_size(raw_yaml_value, unit=None):
    if raw_yaml_value is None:
        val, txt = None, ''
    else:
        val = raw_yaml_value.lower()
        # Convert all values to kb:
        if 'k' in val:
            val = val.replace('k', '').replace('b', '')
            val = float(val)
        elif 'm' in val:
            val = val.replace('m', '').replace('b', '')
            val = float(val) * 1024
        elif 'g' in val:
            val = val.replace('g', '').replace('b', '').replace('i', '')
            val = float(val) * 1024 * 1024
        txt = "%0.2f Kb" % val

        # Then possibly change unit:
        if unit is not None:
            if unit.lower() == 'mb':
                val = val / 1024
                txt = "%0.2f Mb" % val
            elif unit.lower() == 'gb':
                val = val / 1024 / 1024
                txt = "%0.2f Gb" % val

    return val, txt

def readthiskey(run, keys):
    val = None
    if len(keys) == 1:
        if keys[0] in run:
            val = run[keys[0]]
        else:
            raise ValueError("%s not found" % keys[0])
    if len(keys) == 2:
        if keys[1] in run[keys[0]]:
            val = run[keys[0]][keys[1]]
        else:
            raise ValueError("%s not found" % keys[1])
    if len(keys) == 3:
        if keys[2] in run[keys[0]][keys[1]]:
            val = run[keys[0]][keys[1]][keys[2]]
        else:
            raise ValueError("%s not found" % keys[2])
    if len(keys) == 4:
        if keys[3] in run[keys[0]][keys[1]][keys[2]]:
            val = run[keys[0]][keys[1]][keys[2]][keys[3]]
        else:
            raise ValueError("%s not found" % keys[3])
    return val

def convertthiskeyvalue(val, key, unit=None):
    if key in ['walltime', 'cput']:
        val, txt = read_a_timestamp(val, unit=unit)

    if key in ['mem', 'vmem', 'size-on-disk']:
        val, txt = read_a_file_size(val, unit=unit)

    return val

def listvalues(runs, keys, unit=None, sort=None):
    results = {}
    for run in runs:
        if "template" not in run:
            value = readthiskey(runs[run], keys)
            if value is not None:
                value = convertthiskeyvalue(value, keys[-1], unit=unit)
                results.update({run: value})
    return sort_dict_by_value(results, sort=sort)

# %%
grep = 'GSE-ext'

class some_args():
    sort = 'ascent'
    sortby = None
    sortby = 'sim.size'
    # sortby = 'pbs.vmem'

    reverse = False
    reverse = True
args = some_args()

# args = {'reverse': False, 'sortby': None}

if args.sortby is not None:
    if args.sortby in ['pbs.mem', 'mem']:
        keys = ['pbs', 'resources_used', 'mem']
    elif args.sortby in ['pbs.vmem', 'vmem']:
        keys = ['pbs', 'resources_used', 'vmem']
    elif args.sortby in ['pbs.cpupercent', 'cpupercent']:
        keys = ['pbs', 'resources_used', 'cpupercent']
    elif args.sortby in ['pbs.cput', 'cput']:
        keys = ['pbs', 'resources_used', 'cput']
    elif args.sortby in ['pbs.ncpus', 'ncpus']:
        keys = ['pbs', 'resources_used', 'ncpus']
    elif args.sortby in ['pbs.walltime', 'walltime']:
        keys = ['pbs', 'resources_used', 'walltime']
    elif args.sortby in ['sim.traj', 'traj']:
        keys = ['output', 'array-size', 'traj']
    elif args.sortby in ['sim.obs', 'obs']:
        keys = ['output', 'array-size', 'obs']
    elif args.sortby in ['sim.size', 'size']:
        keys = ['output', 'size-on-disk']
    listedvalues = listvalues(run_list, keys, sort=args.sort)
    run_order = listedvalues.keys()
    run_order = run_order if not args.reverse else reversed(run_order)
else:
    listedvalues = None
    run_order = run_list.keys() if not args.reverse else reversed(run_list.keys())

print(run_order)        
        
keys = []
for run in run_order:
    if 'template' not in run and grep in run_list[run]['comment']:
        keys.append(run)
keys
# Out:
# <dict_reversekeyiterator object at 0x165a01b80>
# ['run-1009214', 'run-1009216', 'run-1010801']

# %%
run_list.keys()
# Out:
# dict_keys(['run-template', 'run-1010801', 'run-1009216', 'run-1009214', 'run-1009213', 'run-0923846', 'run-0913494', 'run-0912543', 'run-0908795', 'run-0885949', 'run-0851194', 'run-0711242', 'run-0691822', 'run-0653526', 'run-0614790', 'run-0613257', 'run-0542230', 'run-0538001'])

# %%
import collections
od = collections.OrderedDict(sorted(DB['simulations'].items(), reverse=True))
DB['simulations'] = od
DB['simulations'].keys()
# Out:
# odict_keys(['run-template', 'run-923846', 'run-913494', 'run-912543', 'run-908795', 'run-885949', 'run-851194', 'run-711242', 'run-691822', 'run-653526', 'run-614790', 'run-613257', 'run-542230', 'run-538001', 'run-1010801', 'run-1009216', 'run-1009214', 'run-1009213'])

# %%
# sorted([run.split("run-")[-1] for run in DB['simulations']])
RUNS = {}
RUNS["run-template"] = DB['simulations']["run-template"]
for run in DB['simulations']:
    if 'template' not in run:
        run_id = int(run.split("run-")[-1])
        # print("%0.7d" % run_id)
        RUNS["run-%0.7d" % run_id] = DB['simulations'][run]
# RUNS.keys()   
od = collections.OrderedDict(sorted(RUNS.items(), reverse=True))
DB['simulations'] = od
DB['simulations'].keys()

# %%
# save_json(DB, '../data/simulations_db.json')
# Out:
# {'thermodynamic': {'GLORYS': {'src': '/home/ref-ocean-reanalysis/global-reanalysis-phy-001-030-daily',
#    'description': 'https://doi.org/10.48670/moi-00021',
#    'comment': None,
#    'size-on-disk': '11.8Tb',
#    'array-size': {'x': 4320, 'y': 2041, 'z': 50},
#    'start': '01/01/1993',
#    'end': '31/12/2018',
#    'step': 'daily'},
#   'GLORYS-NATL-init': {'src': '/home/datawork-lops-bluecloud/natl-reanalysis-phy-001-030-daily',
#    'description': 'https://doi.org/10.48670/moi-00021',
#    'comment': 'Global product subsetted to the North-Atlantic. Deprecated, replaced by GLORYS-NATL',
#    'size-on-disk': '220Gb',
#    'array-size': {'x': 961, 'y': 721, 'z': 41},
#    'domain': {'lon_min': -90,
#     'lon_max': -10,
#     'lat_min': 10,
#     'lat_max': 70,
#     'dpt_min': 0.494025,
#     'dpt_max': 2225.078},
#    'start': '01/01/2008',
#    'end': '31/12/2018',
#    'step': 'daily'},
#   'GLORYS-NATL': {'src': '/home/datawork-lops-bluecloud/natl-reanalysis-phy-001-030-daily',
#    'description': 'https://doi.org/10.48670/moi-00021',
#    'comment': 'Global product subsetted to the North-Atlantic. Only: U, V and SLA subsetted.',
#    'size-on-disk': '243Gb',
#    'array-size': {'x': 1141, 'y': 721, 'z': 41},
#    'domain': {'lon_min': -90,
#     'lon_max': 5,
#     'lat_min': 10,
#     'lat_max': 70,
#     'dpt_min': 0.494025,
#     'dpt_max': 2225.078},
#    'start': '01/01/2008',
#    'end': '31/12/2018',
#    'step': 'daily'}},
#  'paths': {'repo': '/home1/datahome/gmaze/git/github/euroargodev/VirtualFleet_GulfStream',
#   'scratch': '/home1/scratch/gmaze/Projects/EARISE/WP2.3/Gulf_Stream_sim'},
#  'simulations': OrderedDict([('run-template',
#                {'comment': None,
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'default', 'file': None},
#                 'execute': {'duration': 'days=30',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local', 'client': ''}},
#                 'pbs': {'jobid': None,
#                  'log': {'debug': None},
#                  'submit': {'file': '${repo}/local_work/simu04.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '250g'},
#                  'resources_used': {'cpupercent': None,
#                   'cput': None,
#                   'mem': None,
#                   'ncpus': None,
#                   'vmem': None,
#                   'walltime': None}},
#                 'output': {'file': None,
#                  'size-on-disk': None,
#                  'array-size': {'traj': None, 'obs': None},
#                  'index': None}}),
#               ('run-1010801',
#                {'comment': 'Experiment with online change of float params. 10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days) except when they enter the GSE-extended area, parking depth is set to 1500 days. All floats cycled up to 300 times.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'gse-experiment',
#                  'file': '/home1/datahome/gmaze/git/github/euroargodev/VirtualFleet_GulfStream/data/vf-floatcfg-gse-experiment-N300-10days-1500drift-GSEext.json',
#                  'area_cycle_duration': 240.0,
#                  'area_parking_depth': 1500.0,
#                  'area_xmax': -35.0,
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'client': {'processes': 8,
#                    'threads': 56,
#                    'memory': '60.00 Gib',
#                    'dashboard': 'http://127.0.0.1:8787/status'}}},
#                 'pbs': {'jobid': '1010801',
#                  'log': {'debug': '${scratch}/logs/logger-1010801.datarmor0.log',
#                   'pbs': '${scratch}/logs/Virt_Fleet.o1010801',
#                   'script': '${scratch}/logs/stdout-1010801.datarmor0.log'},
#                  'submit': {'file': '/home1/datahome/gmaze/scratch/Projects/EARISE/WP2.3/Gulf_Stream_sim/simu08/vf-simu-natl-1010801.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '60g'},
#                  'resources_used': {'cpupercent': None,
#                   'cput': None,
#                   'mem': None,
#                   'ncpus': None,
#                   'vmem': None,
#                   'walltime': None}},
#                 'output': {'file': None,
#                  'size-on-disk': None,
#                  'array-size': {'traj': None, 'obs': None},
#                  'index': None}}),
#               ('run-1009216',
#                {'comment': 'Experiment with online change of float params. 10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days) except when they enter the GSE-extended area, cycling frequency is set to 5 days and parking depth to 1500 days. All floats cycled up to 300 times.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'gse-experiment',
#                  'file': '${repo}/data/vf-floatcfg-gse-experiment-N300-5days-1500drift-GSEext.json',
#                  'area_cycle_duration': 120.0,
#                  'area_parking_depth': 1500.0,
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'client': {'processes': 8,
#                    'threads': 56,
#                    'memory': '60.00 GiB'}}},
#                 'pbs': {'jobid': '1009216',
#                  'log': {'debug': '${scratch}/logs/logger-1009216.datarmor0.log',
#                   'pbs': '${scratch}/logs/Virt_Fleet.o1009216',
#                   'script': '${scratch}/logs/stdout-1009216.datarmor0.log'},
#                  'submit': {'file': '${scratch}/simu08/vf-simu-natl-1009216.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '60g'},
#                  'resources_used': {'cpupercent': None,
#                   'cput': None,
#                   'mem': None,
#                   'ncpus': None,
#                   'vmem': None,
#                   'walltime': None}},
#                 'output': {'file': None,
#                  'size-on-disk': None,
#                  'array-size': {'traj': None, 'obs': None},
#                  'index': None}}),
#               ('run-1009214',
#                {'comment': 'Experiment with online change of float params. 10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days) except when they enter the GSE-extended area, cycle frequency is temporarily set to 5 days. All floats cycled up to 300 times.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'gse-experiment',
#                  'file': '${repo}/data/vf-floatcfg-gse-experiment-N300-5days-GSEext.json',
#                  'area_xmax': -35.0,
#                  'area_cycle_duration': 120.0,
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'client': {'processes': 8,
#                    'threads': 56,
#                    'memory': '60.00 GiB'}}},
#                 'pbs': {'jobid': '1009214',
#                  'log': {'debug': '${scratch}/logs/logger-1009214.datarmor0.log',
#                   'pbs': '${scratch}/logs/Virt_Fleet.o1009214',
#                   'script': '${scratch}/logs/stdout-1009214.datarmor0.log'},
#                  'submit': {'file': '/home1/datahome/gmaze/scratch/Projects/EARISE/WP2.3/Gulf_Stream_sim/simu08/vf-simu-natl-1009214.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '60g'},
#                  'resources_used': {'cpupercent': None,
#                   'cput': None,
#                   'mem': None,
#                   'ncpus': None,
#                   'vmem': None,
#                   'walltime': None}},
#                 'output': {'file': None,
#                  'size-on-disk': None,
#                  'array-size': {'traj': None, 'obs': None},
#                  'index': None}}),
#               ('run-1009213',
#                {'comment': 'Experiment with online change of float params. 10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days) except when they enter the GSE area, cycling frequency is set to 5 days and parking depth to 1500 days. All floats cycled up to 300 times.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'gse-experiment',
#                  'file': '${repo}/data/vf-floatcfg-gse-experiment-N300-5days-1500drift.json',
#                  'area_parking_depth': 1500.0,
#                  'area_xmax': -35.0,
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'client': {'processes': 8,
#                    'threads': 56,
#                    'memory': '60.00 GiB'}}},
#                 'pbs': {'jobid': '1009213',
#                  'log': {'debug': '${scratch}/logs/logger-1009213.datarmor0.log',
#                   'pbs': '${scratch}/logs/Virt_Fleet.o1009213',
#                   'script': '${scratch}/logs/stdout-1009213.datarmor0.log'},
#                  'submit': {'file': '${scratch}/simu08/vf-simu-natl-1009213.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '60g'},
#                  'resources_used': {'cpupercent': None,
#                   'cput': None,
#                   'mem': None,
#                   'ncpus': None,
#                   'vmem': None,
#                   'walltime': None}},
#                 'output': {'file': None,
#                  'size-on-disk': None,
#                  'array-size': {'traj': None, 'obs': None},
#                  'index': None}}),
#               ('run-0923846',
#                {'comment': "Control simulation set-up. Test with 'mpirun -np 28', ncpus=28 on 'omp' queue, no Dask. Also with circular GLORYS-NATL. Killed before the end of the job (exceed 48h walltime).",
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'default',
#                  'file': '/home1/datahome/gmaze/git/github/euroargodev/VirtualFleet_GulfStream/data/vf-floatcfg-default-N300.json',
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'None', 'client': ''}},
#                 'pbs': {'jobid': '923846',
#                  'log': {'debug': '${scratch}/logs/logger-923846.datarmor0.log',
#                   'pbs': '${scratch}/logs/Virt_Fleet.o923846',
#                   'script': '${scratch}/logs/stdout-923846.datarmor0.log'},
#                  'submit': {'file': '/home1/datahome/gmaze/scratch/Projects/EARISE/WP2.3/Gulf_Stream_sim/simu08/vf-simu-natl-923846.pbs',
#                   'queue': 'omp',
#                   'walltime': '48:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 2534,
#                   'cput': '1219:02:16',
#                   'mem': '104857600kb',
#                   'ncpus': '28',
#                   'vmem': '36492kb',
#                   'walltime': '48:05:30'}},
#                 'output': {'file': None,
#                  'size-on-disk': None,
#                  'array-size': {'traj': None, 'obs': None},
#                  'index': None}}),
#               ('run-0913494',
#                {'comment': "Control simulation set-up. Test with mpirun (no arg.), ncpus=28 on 'mpi' queue, with dask. Also with circular GLORYS-NATL. Killed before the end of the job (exceed 48h walltime).",
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'default',
#                  'file': '/home1/datahome/gmaze/git/github/euroargodev/VirtualFleet_GulfStream/data/vf-floatcfg-default-N300.json',
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'client': {'memory': '125.81GiB',
#                    'processes': '8',
#                    'threads': '56'}}},
#                 'pbs': {'jobid': '913494',
#                  'log': {'debug': '${scratch}/logs/logger-913494.datarmor0.log',
#                   'pbs': '${scratch}/logs/Virt_Fleet.o913494',
#                   'script': '${scratch}/logs/stdout-913494.datarmor0.log'},
#                  'submit': {'file': '/home1/datahome/gmaze/scratch/Projects/EARISE/WP2.3/Gulf_Stream_sim/simu08/vf-simu-natl-913494.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 294,
#                   'cput': '141:31:26',
#                   'mem': '54886304kb',
#                   'ncpus': '28',
#                   'vmem': '36500kb',
#                   'walltime': '48:05:13'}},
#                 'output': {'file': '${scratch}/simu08/rdnwrd0e.nc',
#                  'size-on-disk': None,
#                  'array-size': {'traj': None, 'obs': None},
#                  'index': None}}),
#               ('run-0912543',
#                {'comment': 'Control simulation set-up with circular GLORYS-NATL. Replay run-613257 for test purposes.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'default',
#                  'file': '/home1/datahome/gmaze/git/github/euroargodev/VirtualFleet_GulfStream/data/vf-floatcfg-default-N300.json',
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'client': {'memory': '60.00GiB',
#                    'processes': '8',
#                    'threads': '56'}}},
#                 'pbs': {'jobid': '912543',
#                  'log': {'debug': '${scratch}/logs/logger-912543.datarmor0.log',
#                   'pbs': '${scratch}/logs/Virt_Fleet.o912543',
#                   'script': '${scratch}/logs/stdout-912543.datarmor0.log'},
#                  'submit': {'file': '/home1/datahome/gmaze/scratch/Projects/EARISE/WP2.3/Gulf_Stream_sim/simu08/vf-simu-natl-912543.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 106,
#                   'cput': '43:04:29',
#                   'mem': '35591164kb',
#                   'ncpus': '28',
#                   'vmem': '61548200kb',
#                   'walltime': '40:29:15'}},
#                 'output': {'file': '/home1/datahome/gmaze/scratch/Projects/EARISE/WP2.3/Gulf_Stream_sim/simu08/vf-simu-natl-912543.nc',
#                  'size-on-disk': '8.0gb',
#                  'array-size': {'traj': 1484, 'obs': 144017},
#                  'index': '/home1/datahome/gmaze/scratch/Projects/EARISE/WP2.3/Gulf_Stream_sim/simu08/vf-simu-natl-912543_ar_index_prof.txt'}}),
#               ('run-0908795',
#                {'comment': "Control simulation set-up. Test with ncpus=28 on 'omp' queue, with dask and 96 hours of walltime. Killed before end of the job (exceed 96h walltime !).",
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'default',
#                  'file': '/home1/datahome/gmaze/git/github/euroargodev/VirtualFleet_GulfStream/data/vf-floatcfg-default-N300.json',
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'client': {'memory': '100.00GiB',
#                    'processes': '2',
#                    'threads': '28'},
#                   'overrides': {'cluster.n_workers': 2}}},
#                 'pbs': {'jobid': '908795',
#                  'log': {'debug': '${scratch}/logs/logger-908795.datarmor0.log',
#                   'pbs': '${scratch}/logs/Virt_Fleet.o908795',
#                   'script': '${scratch}/logs/stdout-908795.datarmor0.log'},
#                  'submit': {'file': '/home1/datahome/gmaze/scratch/Projects/EARISE/WP2.3/Gulf_Stream_sim/simu08/vf-simu-natl-908795.pbs',
#                   'queue': 'omp',
#                   'walltime': '96:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 103,
#                   'cput': '99:00:47',
#                   'mem': '15438944kb',
#                   'ncpus': '28',
#                   'vmem': '31717276kb',
#                   'walltime': '96:02:45'}},
#                 'output': {'file': None,
#                  'size-on-disk': None,
#                  'array-size': {'traj': None, 'obs': None},
#                  'index': None}}),
#               ('run-0885949',
#                {'comment': "10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days). All floats cycled up to 300 times. This is a 'control' run. Job killed before 10 years.",
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'default',
#                  'file': '/home1/datahome/gmaze/git/github/euroargodev/VirtualFleet_GulfStream/data/vf-floatcfg-default-N300.json',
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'client': {'memory': '60.00GiB',
#                    'processes': '2',
#                    'threads': '56'},
#                   'overrides': {'cluster.n_workers': 2}}},
#                 'pbs': {'jobid': '885949',
#                  'log': {'debug': '${scratch}/logs/logger-885949.datarmor0.log',
#                   'pbs': '${scratch}/logs/Virt_Fleet.o885949',
#                   'script': '${scratch}/logs/stdout-885949.datarmor0.log'},
#                  'submit': {'file': '/home1/datahome/gmaze/scratch/Projects/EARISE/WP2.3/Gulf_Stream_sim/simu08/vf-simu-natl-885949.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 103,
#                   'cput': '49:34:09',
#                   'mem': '9884768kb',
#                   'ncpus': '28',
#                   'vmem': '24932996kb',
#                   'walltime': '48:01:18'}},
#                 'output': {'file': None,
#                  'size-on-disk': None,
#                  'array-size': {'traj': None, 'obs': None},
#                  'index': None}}),
#               ('run-0851194',
#                {'comment': '8 years (2008/1-2016/3) simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days) except when they enter the GSE area, parking_depth is temporarily set to 1500m. All floats cycled up to 300 times. Job killed before 10 years',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'name': 'gse-experiment',
#                  'file': '/home1/datahome/gmaze/git/github/euroargodev/VirtualFleet_GulfStream/data/vf-floatcfg-gse-experiment-N300-10days-1500drift.json',
#                  'area_cycle_duration': 240.0,
#                  'area_parking_depth': 1500.0,
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'overrides': {'cluster.n_workers': 56},
#                   'client': {'memory': '60.00GiB',
#                    'processes': '56',
#                    'threads': '56'}}},
#                 'pbs': {'jobid': '851194',
#                  'log': {'debug': '${scratch}/logs/logger-851194.datarmor0.log',
#                   'pbs': '${scratch}/logs/Virt_Fleet.o851194',
#                   'script': '${scratch}/logs/stdout-851194.datarmor0.log'},
#                  'submit': {'file': '/home1/datahome/gmaze/scratch/Projects/EARISE/WP2.3/Gulf_Stream_sim/simu08/vf-simu-natl-851194.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 165,
#                   'cput': '79:38:20',
#                   'mem': '18374560kb',
#                   'ncpus': '28',
#                   'vmem': '265658036kb',
#                   'walltime': '48:04:27'}},
#                 'output': {'file': '${scratch}/simu08/vf-simu-natl-851194.nc',
#                  'size-on-disk': '6.8Gb',
#                  'array-size': {'traj': 1249, 'obs': 144017},
#                  'index': '${scratch}/simu08/vf-simu-natl-851194_ar_index_prof.txt'}}),
#               ('run-0711242',
#                {'comment': '4th experiment. 10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days) except when they enter the GSE area (Argo-AST definition), parking_depth is temporarily set to 1500m. All floats cycled up to 300 times.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'file': '${scratch}/simu07/vf-simu-natl-711242_floatcfg.json',
#                  'name': 'gse-experiment',
#                  'life_expectancy': 300,
#                  'area_cycle_duration': '10 * 24',
#                  'area_parking_depth': 1500,
#                  'area_xmin': -75,
#                  'area_xmax': -30,
#                  'area_ymin': 36,
#                  'area_ymax': 51},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'overrides': {'cluster.n_workers': None},
#                   'client': ''}},
#                 'pbs': {'jobid': 711242,
#                  'log': {'pbs': '${scratch}/logs/Virt_Fleet.o711242',
#                   'debug': '${scratch}/logs/simu07-batch-711242.datarmor0.log',
#                   'script': '${scratch}/simu07/simu07-711242.datarmor0.log'},
#                  'submit': {'file': '${repo}/local_work/simu07.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 107,
#                   'cput': '43:56:43',
#                   'mem': '35273264kb',
#                   'ncpus': 28,
#                   'vmem': '61203788kb',
#                   'walltime': '40:59:53'}},
#                 'output': {'file': '${scratch}/simu07/vf-simu-natl-711242.nc',
#                  'size-on-disk': '8gb',
#                  'array-size': {'traj': 1484, 'obs': 144023},
#                  'index': '${scratch}/simu07/vf-simu-natl-711242_ar_index_prof.txt'}}),
#               ('run-0691822',
#                {'comment': '3rd experiment. 10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days) except when they enter the GSE area (Argo-AST definition), cycle_period is temporarily set to 5 days. All floats cycled up to 300 times.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'file': '${scratch}/simu07/vf-simu-natl-691822_floatcfg.json',
#                  'name': 'gse-experiment',
#                  'life_expectancy': 300,
#                  'area_cycle_duration': '5 * 24',
#                  'area_xmin': -75,
#                  'area_xmax': -30,
#                  'area_ymin': 36,
#                  'area_ymax': 51},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'overrides': {'cluster.n_workers': None},
#                   'client': ''}},
#                 'pbs': {'jobid': 691822,
#                  'log': {'pbs': '${scratch}/logs/Virt_Fleet.o691822',
#                   'debug': '${scratch}/logs/simu07-batch-691822.datarmor0.log',
#                   'script': '${scratch}/simu07/simu07-691822.datarmor0.log'},
#                  'submit': {'file': '${repo}/local_work/simu07.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 107,
#                   'cput': '47:29:34',
#                   'mem': '35015004kb',
#                   'ncpus': 28,
#                   'vmem': '63054384kb',
#                   'walltime': '44:07:37'}},
#                 'output': {'file': '${scratch}/simu07/vf-simu-natl-691822.nc',
#                  'size-on-disk': '8gb',
#                  'array-size': {'traj': 1484, 'obs': 144017},
#                  'index': '${scratch}/simu07/vf-simu-natl-691822_ar_index_prof.txt'}}),
#               ('run-0653526',
#                {'comment': '2nd experiment with online change of float params. 10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days) except when they enter the GSE area, parking_depth is temporarily set to 1500m. All floats cycled up to 300 times.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'file': '${scratch}/simu07/vf-simu-natl-653526_floatcfg.json',
#                  'name': 'gse-experiment',
#                  'life_expectancy': 300,
#                  'area_cycle_duration': '10 * 24',
#                  'area_parking_depth': 1500,
#                  'area_xmin': -75,
#                  'area_xmax': -48,
#                  'area_ymin': 33,
#                  'area_ymax': 45.5},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'overrides': {'cluster.n_workers': None},
#                   'client': ''}},
#                 'pbs': {'jobid': 653526,
#                  'log': {'pbs': '${scratch}/logs/Virt_Fleet.o653526',
#                   'debug': '${scratch}/logs/simu07-batch-653526.datarmor0.log'},
#                  'submit': {'file': '${repo}/local_work/simu07.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 108,
#                   'cput': '45:42:08',
#                   'mem': '35090824kb',
#                   'ncpus': 28,
#                   'vmem': '60958372kb',
#                   'walltime': '42:04:32'}},
#                 'output': {'file': '${scratch}/simu07/vf-simu-natl-653526.nc',
#                  'size-on-disk': '8Gb',
#                  'array-size': {'traj': 1484, 'obs': 144017},
#                  'index': '${scratch}/simu07/vf-simu-natl-653526_ar_index_prof.txt'}}),
#               ('run-0614790',
#                {'comment': '1st experiment with online change of float params. 10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days) except when they enter the GSE area, cycle_period is temporarily set to 5 days. All floats cycled up to 300 times.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'file': '${scratch}/simu07/vf-simu-natl-614790_floatcfg.json',
#                  'name': 'gse-experiment',
#                  'life_expectancy': 300,
#                  'area_cycle_duration': '5 * 24',
#                  'area_xmin': -75,
#                  'area_xmax': -48,
#                  'area_ymin': 33,
#                  'area_ymax': 45.5},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'overrides': {'cluster.n_workers': 56},
#                   'client': ''}},
#                 'pbs': {'jobid': 614790,
#                  'log': {'pbs': '${scratch}/logs/Virt_Fleet.o614790',
#                   'debug': '${scratch}/logs/simu07-batch-614790.datarmor0.log'},
#                  'submit': {'file': '${repo}/local_work/simu07.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 162,
#                   'cput': '12:11:53',
#                   'mem': '37478588kb',
#                   'ncpus': 28,
#                   'vmem': '270668888kb',
#                   'walltime': '44:28:53'}},
#                 'output': {'file': '${scratch}/simu07/vf-simu-natl-614790.nc',
#                  'size-on-disk': '8Gb',
#                  'array-size': {'traj': 1484, 'obs': 144012},
#                  'index': '${scratch}/simu07/vf-simu-natl-614790_ar_index_prof.txt'}}),
#               ('run-0613257',
#                {'comment': "Second 10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days). All floats cycled up to 300 times. This is the 'control' run.",
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL'},
#                 'argo-configuration': {'file': '${scratch}/simu04/vf-simu-natl-613257_floatcfg.json',
#                  'name': 'default',
#                  'life_expectancy': 300},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'overrides': {'cluster.n_workers': 56},
#                   'client': ''}},
#                 'runs-on': 'datarmor',
#                 'pbs': {'jobid': 613257,
#                  'log': {'pbs': '${scratch}/logs/VirtualFleet.o613257',
#                   'debug': '${scratch}/logs/simu04-batch-613257.datarmor0.log'},
#                  'submit': {'file': '${repo}/local_work/simu04.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '100g'},
#                  'resources_used': {'cpupercent': 161,
#                   'cput': '08:41:48',
#                   'mem': '38619288kb',
#                   'ncpus': 28,
#                   'vmem': '268121036kb',
#                   'walltime': '42:27:50'}},
#                 'output': {'file': '${scratch}/simu04/vf-simu-natl-613257.nc',
#                  'size-on-disk': '8Gb',
#                  'array-size': {'traj': 1484, 'obs': 144017},
#                  'index': '${scratch}/simu04/vf-simu-natl-613257_ar_index_prof.txt'}}),
#               ('run-0542230',
#                {'comment': 'First successful 10 years simulation with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days). All floats cycled infinitely to the end of the simulation. Velocity field is the initial version that stops at 10W.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL-init'},
#                 'argo-configuration': {'name': 'default'},
#                 'execute': {'duration': 'days=365*10',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'overrides': {'cluster.n_workers': None},
#                   'client': ''}},
#                 'pbs': {'jobid': 542230,
#                  'log': {'pbs': '${repo}/local_work/simu04.pbs.o542230',
#                   'debug': '${repo}/local_work/simu04-batch-542230.datarmor0.log'},
#                  'submit': {'file': '${repo}/local_work/simu04.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '250g'},
#                  'resources_used': {'cpupercent': 107,
#                   'cput': '41:26:14',
#                   'mem': '35732992kb',
#                   'ncpus': 28,
#                   'vmem': '60153420kb',
#                   'walltime': '38:26:00'}},
#                 'output': {'file': '${scratch}/simu04/vf-simu-natl-542230.nc',
#                  'size-on-disk': '11Gb',
#                  'array-size': {'traj': 1484, 'obs': 175201}}}),
#               ('run-0538001',
#                {'comment': '1 year simulation only (2018) with full deployment plan. Floats config all default (drift:1000m, profD:2000m, cycle_period:10 days). All floats cycled infinitely to the end of the simulation. Velocity field is the initial version that stops at 10W.',
#                 'runs-on': 'datarmor',
#                 'deployment-plan': {'src': '${repo}/data/2008-2018-Deployment-Plan.json',
#                  'start': '01/01/2008',
#                  'end': '31/12/2018',
#                  'float-number': 1648},
#                 'velocity-field': {'name': 'GLORYS-NATL-init'},
#                 'argo-configuration': {'name': 'default'},
#                 'execute': {'duration': 'days=365',
#                  'step': 'minutes=5',
#                  'record': 'seconds=3600/2',
#                  'dask_hpcconfig': {'name': 'datarmor-local',
#                   'overrides': {'cluster.n_workers': None}}},
#                 'pbs': {'jobid': 538001,
#                  'log': {'pbs': '${repo}/local_work/simu.pbs.o538001',
#                   'debug': None},
#                  'submit': {'file': '${repo}/local_work/simu.pbs',
#                   'queue': 'mpi',
#                   'walltime': '48:00:00',
#                   'mem': '250g'},
#                  'resources_used': {'cpupercent': 107,
#                   'cput': '43:53:18',
#                   'mem': '40399432kb',
#                   'ncpus': 28,
#                   'vmem': '69993320kb',
#                   'walltime': '40:53:34'}},
#                 'output': {'file': '/home1/datawork/gmaze/Projects/EARISE/WP2.3/Gulf_Stream_sim/3a1n556x.nc',
#                  'size-on-disk': '331Mb',
#                  'array-size': {'traj': 449, 'obs': 17521}}})])}
# 2022-07-11 14:37:05,202 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client

# %%
run_list['run-711242']['pbs']['resources_used']['walltime']
# Out:
# 147593

# %%
def sexagesimal2timedelta(sex):
    # https://stackoverflow.com/questions/52732222/in-the-yaml-format-file-as-test-yaml-some-mac-addresses-will-be-judged-as-numbe
    a, SS = np.divmod(sex, 60)
    a, MM = np.divmod(a, 60)
    a, HH = np.divmod(a, 60)
    return pd.Timedelta(SS+MM*60+HH*3600, unit='sec')

def sexagesimal2str(sex):
    val = sexagesimal2timedelta(sex)
    HH = np.fix(val.total_seconds() / 60 / 60)
    MM = np.fix((val.total_seconds() - HH*60*60) / 60)
    SS = val.total_seconds() - HH*60*60 - MM*60
    return "%0.2d:%0.2d:%0.2d" % (HH,MM,SS)

raw_yaml_value = run_list['run-711242']['pbs']['resources_used']['walltime']

# val = sexagesimal2timedelta(raw_yaml_value)
val = sexagesimal2str(raw_yaml_value)
val
# Out:
# '40:59:53'

# %%
for run in DB['simulations']:
    raw_yaml_value = DB['simulations'][run]['pbs']['resources_used']['walltime']
    if raw_yaml_value is not None:
        val = sexagesimal2str(raw_yaml_value)
        print(run, raw_yaml_value, val)
        DB['simulations'][run]['pbs']['resources_used']['walltime'] = val
        
    raw_yaml_value = DB['simulations'][run]['pbs']['resources_used']['cput']
    if raw_yaml_value is not None:
        val = sexagesimal2str(raw_yaml_value)
        print(run, raw_yaml_value, val)
        DB['simulations'][run]['pbs']['resources_used']['cput'] = val
# Out:
# run-777823 172974 48:02:54
# run-777823 190207 52:50:07
# run-711242 147593 40:59:53
# run-711242 158203 43:56:43
# run-691822 158857 44:07:37
# run-691822 170974 47:29:34
# run-653526 151472 42:04:32
# run-653526 164528 45:42:08
# run-614790 160133 44:28:53
# run-614790 259913 12:11:53
# run-613257 152870 42:27:50
# run-613257 247308 08:41:48
# run-542230 138360 38:26:00
# run-542230 149174 41:26:14
# run-538001 147214 40:53:34
# run-538001 157998 43:53:18

# %%
run_list['run-711242']['pbs']['resources_used']['walltime']
# Out:
# '40:59:53'

# %%
with open("../data/simulations_db.json3", 'w') as stream:
    json.dump(DB, stream, indent=2)

# %%
def str2timedelta(txt):
    """Convert HH:MM:SS string to Timedelta"""
    HH = txt.split(":")[0]
    MM = txt.split(":")[1]
    SS = txt.split(":")[2]
    return pd.Timedelta(SS+MM*60+HH*3600, unit='sec')
str2timedelta("38:26:00")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 7>()
#       5     SS = txt.split(":")[2]
#       6     return pd.Timedelta(SS+MM*60+HH*3600, unit='sec')
# ----> 7 str2timedelta("38:26:00")
#
# Input In [51], in str2timedelta(txt)
#       4 MM = txt.split(":")[1]
#       5 SS = txt.split(":")[2]
# ----> 6 return pd.Timedelta(SS+MM*60+HH*3600, unit='sec')
#
# File ~/miniconda3/envs/virtualfleet/lib/python3.8/site-packages/pandas/_libs/tslibs/timedeltas.pyx:1338, in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# ValueError: unit must not be specified if the value is a str

# %%
pd.Timedelta("38:26:00")
# Out:
# Timedelta('1 days 14:26:00')

# %%
import os
os.getenv('PBS_JOBID') if os.getenv('PBS_JOBID') else ""
# Out:
# ''

# %%
from datetime import timedelta
duration = "days=365*10"
eval("timedelta(%s)" % duration)
# Out:
# datetime.timedelta(days=3650)

# %%
resources_used = {
          "cpupercent": 0,
          "cput": "",
          "mem": "",
          "ncpus": 0,
          "vmem": "",
          "walltime": ""
        }

s = """
PBS Job Id: 1132757.datarmor0
Job Name:   Virt_Fleet
Execution terminated
Exit_status=0
resources_used.cpupercent=108
resources_used.cput=45:39:36
resources_used.mem=35449048kb
resources_used.ncpus=28
resources_used.vmem=63648244kb
resources_used.walltime=41:57:17
"""

for line in s.split("\n"):
    if '.cpupercent' in line:
        resources_used['cpupercent'] = int(line.split("=")[-1])
    if '.cput' in line:
        resources_used['cput'] = line.split("=")[-1]
    if '.mem' in line:
        resources_used['mem'] = line.split("=")[-1]
    if '.ncpus' in line:
        resources_used['ncpus'] = line.split("=")[-1]
    if '.vmem' in line:
        resources_used['vmem'] = line.split("=")[-1]
    if '.walltime' in line:
        resources_used['walltime'] = line.split("=")[-1]
        
print(json.dumps(resources_used)        )
# Out:
# {"cpupercent": 108, "cput": "45:39:36", "mem": "35449048kb", "ncpus": "28", "vmem": "63648244kb", "walltime": "41:57:17"}

# %%
json.dumps(resources_used)
# Out:
# '{"cpupercent": 165, "cput": "79:49:07", "mem": "18367108kb", "ncpus": "28", "vmem": "265668188kb", "walltime": "48:05:09"}'

# %%
last_line = " 34% (894600.0 of 2592000.0) |###        | Elapsed Time: 0:04:08 ETA:   0:10:02"
last_line.split("%")[0]
# Out:
# ' 34'

# %%
pd.to_datetime('07/08/2022 06:52:54') - pd.to_datetime('07/06/2022 02:19:03')
# Out:
# Timedelta('2 days 04:33:51')
